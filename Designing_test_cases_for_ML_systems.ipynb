# %% [markdown]
# <a href="https://colab.research.google.com/github/MthabisiPatrice/ML-Engineering/blob/main/Designing_test_cases_for_ML_systems.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Step-by-step process to design test cases for ML systems
# Create a new Jupyter notebook. Make sure you have the appropriate Python 3.8 Azure ML kernel selected.
#
# The remaining of this reading will guide you through the following steps:
#
# Step 1: Set up the environment
#
# Step 2: Define test cases for typical scenarios
#
# Step 3: Design test cases for edge scenarios
#
# Step 4: Create error-handling test cases
#
# Step 5: Automate test case execution
#
# Step 6: Evaluate the effectiveness of your test cases
#
# #Step 1: Set up the environment
# Begin by setting up your Python environment. Make sure you have a testing framework like pytest or unittest installed to support automated testing.
#
# Setup commands

# %%
# !pip install pytest
# !pip install ipytest
# Out:
# Requirement already satisfied: pytest in /usr/local/lib/python3.12/dist-packages (8.4.2)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.12/dist-packages (from pytest) (2.3.0)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.12/dist-packages (from pytest) (26.2)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from pytest) (2.20.0)
# Collecting ipytest
#   Downloading ipytest-0.14.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: ipython in /usr/local/lib/python3.12/dist-packages (from ipytest) (7.34.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from ipytest) (26.2)
# Requirement already satisfied: pytest>=5.4 in /usr/local/lib/python3.12/dist-packages (from ipytest) (8.4.2)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.12/dist-packages (from pytest>=5.4->ipytest) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest>=5.4->ipytest) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from pytest>=5.4->ipytest) (2.20.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython->ipytest) (75.2.0)
# Collecting jedi>=0.16 (from ipython->ipytest)
#   Downloading jedi-0.20.0-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython->ipytest) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython->ipytest) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.12/dist-packages (from ipython->ipytest) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython->ipytest) (3.0.52)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython->ipytest) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython->ipytest) (0.2.2)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython->ipytest) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython->ipytest) (0.8.7)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython->ipytest) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->ipytest) (0.8.1)
# Downloading ipytest-0.14.2-py3-none-any.whl (18 kB)
# Downloading jedi-0.20.0-py2.py3-none-any.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 15.4 MB/s eta 0:00:00
# Installing collected packages: jedi, ipytest
# Successfully installed ipytest-0.14.2 jedi-0.20.0

# %% [markdown]
# Explanation
# These libraries will help you automate test case execution and ensure that the test cases can be run efficiently every time your model is updated.
#
# Let’s create a model.

# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier

# Load the dataset
iris = load_iris()
X, y = iris.data, iris.target

# Set up the model
model = DecisionTreeClassifier()
model.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# Here we've used the iris dataset and a decision tree classifier to create a decision tree classifier model.

# %% [markdown]
# #Step 2: Define test cases for typical scenarios
# Start by defining test cases for typical scenarios. These scenarios represent the normal input data your model will frequently encounter during regular operation.
#
# Instructions
# Identify representative input data from your dataset.
#
# Define the expected output for each test case based on your model’s behavior.
#
# Create a set of test cases that cover the most common use cases.
#
# Code example

# %%
def test_typical_case():
    input_data = np.array([[4.5, 2.3, 1.3, 0.3]])  # Example input for a flower classification model
    expected_output = 0  # Expected output for typical case (Setosa class index)
    result = model.predict(input_data)[0]
    assert result == expected_output, f"Expected {expected_output}, but got {result}"

# %% [markdown]
# Explanation
# This test case checks whether the model correctly classifies a typical input, ensuring it handles common situations well.

# %% [markdown]
# #Step 3: Design test cases for edge scenarios
# Next, create test cases that challenge the model with edge scenarios. These tests use data that falls outside the normal range and include extreme or unusual values.
#
# Instructions
# Identify edge cases with unusually high or low values.
#
# Test how the model responds to these edge cases and ensure robustness.
#
# Define the expected output or error handling for each edge case.
#
# Code example

# %%
def test_edge_case_extreme_values():
    input_data = np.array([[1000, 1000, 1000, 1000]])  # Extreme values for flower classification
    try:
        model.predict(input_data)
    except ValueError:
        assert True  # The model should raise a ValueError for extreme inputs
    else:
        assert False, "Expected ValueError for extreme values, but no error was raised"

# %% [markdown]
# Explanation
# Edge case testing ensures that the model doesn’t produce incorrect results or crash when encountering extreme or unusual inputs.

# %% [markdown]
# #Step 4: Create error-handling test cases
# Now create test cases to verify the model’s ability to handle invalid inputs. Error-handling tests check whether the model behaves correctly when it receives flawed or incomplete data.
#
# Instructions
# Create test cases with missing, null, or malformed data.
#
# Ensure that the model handles these cases appropriately, either by returning an error message or handling the input gracefully.
#
# Code example

# %%
def test_error_handling_missing_values():
    input_data = np.array([[None, None, None, None]])  # Missing values in input
    try:
        model.predict(input_data)
    except ValueError:
        assert True  # The model should raise a ValueError for missing inputs
    else:
        assert False, "Expected ValueError for missing values, but no error was raised"

# %% [markdown]
# Explanation
# This test case checks how the model handles missing data, ensuring it doesn’t fail or produce invalid results when inputs are incomplete.

# %% [markdown]
# #Step 5: Automate test case execution
# After defining your test cases, automate the testing process using pytest or unittest. Automation ensures that tests are run every time the model is updated, preventing errors from slipping through.
#
# Instructions
# Write automated tests for each of your test cases.
#
# Use a framework such as pytest to automatically execute all tests.
#
# Set up continuous testing to validate the model after updates or new data are introduced.
#
# Code example (with pytest)

# %%
import ipytest
# Run tests using ipytest
ipytest.run('-v')
# Out:
# ======================================= test session starts ========================================
# platform linux -- Python 3.12.13, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content
# plugins: anyio-4.14.0, typeguard-4.5.2, langsmith-0.9.1
# collecting ... collected 3 items
#
# t_9f06a4e44d19496db6eb4753cae7b660.py::test_typical_case PASSED                              [ 33%]
# t_9f06a4e44d19496db6eb4753cae7b660.py::test_edge_case_extreme_values FAILED                  [ 66%]
# t_9f06a4e44d19496db6eb4753cae7b660.py::test_error_handling_missing_values FAILED             [100%]
#
# ============================================= FAILURES =============================================
# __________________________________ test_edge_case_extreme_values ___________________________________
#
#     def test_edge_case_extreme_values():
#         input_data = np.array([[1000, 1000, 1000, 1000]])  # Extreme values for flower classification
#         try:
#             model.predict(input_data)
#         except ValueError:
#             assert True  # The model should raise a ValueError for extreme inputs
#         else:
# >           assert False, "Expected ValueError for extreme values, but no error was raised"
#                    ^^^^^
# E           AssertionError: Expected ValueError for extreme values, but no error was raised
#
# /tmp/ipykernel_3994/1734168487.py:8: AssertionError
# ________________________________ test_error_handling_missing_values ________________________________
#
#     def test_error_handling_missing_values():
#         input_data = np.array([[None, None, None, None]])  # Missing values in input
#         try:
#             model.predict(input_data)
#         except ValueError:
#             assert True  # The model should raise a ValueError for missing inputs
#         else:
# >           assert False, "Expected ValueError for missing values, but no error was raised"
#                    ^^^^^
# E           AssertionError: Expected ValueError for missing values, but no error was raised
#
# /tmp/ipykernel_3994/3084191689.py:8: AssertionError
# ===================================== short test summary info ======================================
# FAILED t_9f06a4e44d19496db6eb4753cae7b660.py::test_edge_case_extreme_values - AssertionError: Exp...
# FAILED t_9f06a4e44d19496db6eb4753cae7b660.py::test_error_handling_missing_values - AssertionError...
# =================================== 2 failed, 1 passed in 0.11s ====================================
# <ExitCode.TESTS_FAILED: 1>

# %% [markdown]
# Explanation
# Automating test execution ensures that all test cases are checked after each update, helping to catch potential issues before deployment

# %% [markdown]
# Step 6: Evaluate the effectiveness of your test cases
# Finally, evaluate your test cases to ensure they comprehensively cover typical, edge, and error scenarios. Refine them based on the results to improve coverage and accuracy.
#
# Instructions
# Review the test results to ensure the model passes all cases.
#
# Check whether the model behaves as expected in edge and error scenarios.
#
# Improve the test cases if any failures or unexpected behaviors are identified.
#
# Explanation
# Evaluating the effectiveness of your test cases helps ensure that they thoroughly test the model’s behavior and identify any areas where the model might fail.
